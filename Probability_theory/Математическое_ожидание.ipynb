# %% [markdown]
# # Математическое ожидание

# %% [markdown]
# Математи́ческое ожида́ние — понятие в теории вероятностей, означающее среднее (взвешенное по вероятностям возможных значений) значение случайной величины[1]. В случае непрерывной случайной величины подразумевается взвешивание по плотности распределения (более строгие определения см. ниже). Математическое ожидание случайного вектора равно вектору, компоненты которого равны математическим ожиданиям компонентов случайного вектора.

# %% [markdown]
# Обозначается через E[X] (например, от англ. Expected value или нем. Erwartungswert); в русскоязычной литературе также встречается обозначение M[X] (возможно, от англ. Mean value или нем. Mittelwert, а возможно от «Математическое ожидание»). В статистике часто используют обозначение u.

# %% [markdown]
# Для случайной величины, принимающей значения только 0 или 1 математическое ожидание равно p — вероятности «единицы». Математическое ожидание суммы таких случайных величин равно np, где n — количество таких случайных величин. При этом вероятности появления определенного кол-ва единиц рассчитываются по биномиальному распределению. Поэтому в литературе, скорее всего, легче найти запись, что мат. ожидание биномиального распределения равно np.

# %% [markdown]
# Некоторые случайные величины не имеют математического ожидания, например, случайные величины, имеющие распределение Коши.

# %% [markdown]
# На практике математическое ожидание обычно оценивается как среднее арифметическое наблюдаемых значений случайной величины (выборочное среднее, среднее по выборке). Доказано, что при соблюдении определенных слабых условий (в частности, если выборка является случайной, то есть наблюдения являются независимыми) выборочное среднее стремится к истинному значению математического ожидания случайной величины при стремлении объема выборки (количества наблюдений, испытаний, измерений) к бесконечности.

# %% [markdown]
# **Общее определение через интеграл Лебега**
# ---
# Пусть задано вероятностное пространство ![image.png](attachment:image.png) и определённая на нём случайная величина X. То есть, по определению, ![image.png](attachment:image-2.png)  — измеримая функция. Если существует интеграл Лебега от X по пространству ![image.png](attachment:image-3.png) , то он называется математическим ожиданием, или средним (ожидаемым) значением и обозначается M[X] или E[X].

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Определение через функцию распределения случайной величины**
# ---
# Если ![image.png](attachment:image.png) — функция распределения случайной величины, то её математическое ожидание задаётся интегралом Лебега — Стилтьеса:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Определение для абсолютно непрерывной случайной величины (через плотность распределения)**
# ---
# Математическое ожидание абсолютно непрерывной случайной величины, распределение которой задаётся плотностью ![image.png](attachment:image.png), равно

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Определение для дискретной случайной величины**
# ---
# Если X — дискретная случайная величина, имеющая распределение

# %% [markdown]
# ![image.png](attachment:image-2.png), ![image.png](attachment:image.png)

# %% [markdown]
# то прямо из определения интеграла Лебега следует, что

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Математическое ожидание целочисленной величины**
# ---
# Если X — положительная целочисленная случайная величина (частный случай дискретной), имеющая распределение вероятностей

# %% [markdown]
# ![image.png](attachment:image.png), ![image.png](attachment:image-2.png), ![image.png](attachment:image-3.png)

# %% [markdown]
# то её математическое ожидание может быть выражено через производящую функцию последовательности ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# как значение первой производной в единице ![image.png](attachment:image.png) Если математическое ожидание X бесконечно, то ![image.png](attachment:image-2.png) и мы будем писать ![image.png](attachment:image-3.png). Теперь возьмём производящую функцию ![image.png](attachment:image-4.png) последовательности «хвостов» распределения ![image.png](attachment:image-5.png)

# %% [markdown]
# ![image.png](attachment:image.png), ![image.png](attachment:image-2.png)

# %% [markdown]
# Эта производящая функция связана с определённой ранее функцией ![image.png](attachment:image.png) свойством ![image.png](attachment:image-2.png) при ![image.png](attachment:image-3.png). Из этого по теореме о среднем следует, что математическое ожидание равно просто значению этой функции в единице:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Свойства математического ожидания***

# %% [markdown]
# Математическое ожидание числа (не случайной, фиксированной величины, константы) есть само число.

# %% [markdown]
# ![image.png](attachment:image.png)
# ---
# ![image.png](attachment:image-2.png) — константа

# %% [markdown]
# Математическое ожидание линейно, то есть

# %% [markdown]
# ![image.png](attachment:image.png)
# ---
# где ![image.png](attachment:image-2.png) — случайные величины с конечным математическим ожиданием, а ![image.png](attachment:image-3.png) — произвольные константы;

# %% [markdown]
# В частности, математическое ожидание суммы (разности) случайных величин равно сумме (соответственно — разности) их математических ожиданий.
#
# Математическое ожидание сохраняет неравенства, то есть если ![image.png](attachment:image.png) почти наверняка, и Y — случайная величина с конечным математическим ожиданием, то математическое ожидание случайной величины X также конечно, и более того

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Математическое ожидание не зависит от поведения случайной величины на событии вероятности нуль, то есть если ![image.png](attachment:image.png) почти наверняка, то

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Математическое ожидание произведения двух независимых или некоррелированных случайных величин X, Y равно произведению их математических ожиданий

# %% [markdown]
# ![image.png](attachment:image.png)
